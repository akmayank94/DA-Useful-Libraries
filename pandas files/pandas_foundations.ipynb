# %% [markdown]
# #Pandas All Concepts

# %%
# importing pandas
import numpy as np
import pandas as pd

# %% [markdown]
# ##Series made from Lists

# %%
# Series -> columns in the table are called series in pandas. Series is a class inside pandas.
country = ['India','Pakistan','China','Srilanka']
pd.Series(country)

# Notes: In pandas , when we get dtype: object , it means values are in string form. Not in everycase but most of the cases.
#        Series include two things: index and values
#        country is as object of 'Series' class
# Out:
# 0       India
# 1    Pakistan
# 2       China
# 3    Srilanka
# dtype: object

# %%
# integers
runs = [13,45,77,23,55]
pd.Series(runs)
# Out:
# 0    13
# 1    45
# 2    77
# 3    23
# 4    55
# dtype: int64

# %%
# custom index
marks = [67,69,99,10]
subjects = ['maths','science','english','french']

custom = pd.Series(marks,index=subjects)
print(custom)
# Out:
# maths      67
# science    69
# english    99
# french     10
# dtype: int64

# %%
# setting a name
y = pd.Series(marks,index=subjects,name='Marks of Mayank')
print(y)
# Out:
# maths      67
# science    69
# english    99
# french     10
# Name: Marks of Mayank, dtype: int64

# %% [markdown]
# ##Series made from dictionary

# %%
marks = {
    'English':69,
    'Hindi':100,
    'Computer science':100
}

marks_dict = pd.Series(marks)
print(marks_dict)
# Out:
# English              69
# Hindi               100
# Computer science    100
# dtype: int64

# %% [markdown]
# ##Series Attributes

# %%
# size
marks_dict.size
# Out:
# 3

# %%
y.size
# Out:
# 4

# %%
# dtype
y.dtype
# Out:
# dtype('int64')

# %%
# name
y.name
# Out:
# 'Marks of Mayank'

# %%
# is_unique -> tells about all the elements of the series are unique of not
y.is_unique
# Out:
# True

# %%
# index
y.index
# Out:
# Index(['maths', 'science', 'english', 'french'], dtype='object')

# %%
runs = pd.Series([13,45,77,23,55])
runs.index

# RangeIndex is just a special kind of object which store index values
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# values -> gives a numpy array
y.values
# Out:
# array([67, 69, 99, 10])

# %% [markdown]
# ##Series using read_csv

# %%
# with 1 column
subs = pd.read_csv('/content/subs.csv')
print(subs)
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
# with 2 column
vk = pd.read_csv('/content/kohli_ipl.csv',index_col='match_no')
print(vk)
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
movies = pd.read_csv('/content/bollywood.csv',index_col='movie')
print(movies)
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %% [markdown]
# ##Series Methods

# %%
# head and tail
# head -> give data preview only , show first 5 rows from data by dafault BUT we can ask for more by mentioning no. of rows in head()

print(subs.head())
# Out:
#    Subscribers gained
# 0                  48
# 1                  57
# 2                  40
# 3                  43
# 4                  44

# %%
print(vk.tail())
# Out:
#           runs
# match_no
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7

# %%
# sample -> give one row from data randomly
# useful when our data has some bias
print(movies.sample(3))
# Out:
#                                 lead
# movie
# Ghajini (2008 film)       Aamir Khan
# Baby (2015 Hindi film)  Akshay Kumar
# No Entry                 Anil Kapoor

# %%
# value_counts -> tells the frequency for a value present in data in DESC order
print(movies.value_counts())
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Naveen Bawa          1
# Naushaad Abbas       1
# Nauheed Cyrusi       1
# Natalia Janoszek     1
# Nishikant Kamat      1
# Name: count, Length: 566, dtype: int64

# %%
# sort_values
print(vk.sort_values(by='runs',ascending=False))
# Out:
#           runs
# match_no
# 128        113
# 126        109
# 123        108
# 120        100
# 164        100
# ...        ...
# 93           0
# 130          0
# 206          0
# 207          0
# 211          0
#
# [215 rows x 1 columns]

# %%
# we can use head() here also
# THIS IS CALLED METHOD CHAINING
print(vk.sort_values(by='runs',ascending=False).head(3).values[0])
# Out:
# [113]

# %%
# if you want to do permanent changes in dataset , you have to use inplace=True
vk.sort_values(by='runs',inplace=True)

# %%
print(vk)
# Out:
#           runs
# match_no
# 8            0
# 87           0
# 93           0
# 91           0
# 206          0
# ...        ...
# 164        100
# 120        100
# 123        108
# 126        109
# 128        113
#
# [215 rows x 1 columns]

# %%
# sort_index
print(movies.sort_index())
# Out:
#                                         lead
# movie
# 1920 (film)                 Rajniesh Duggall
# 1920: London                   Sharman Joshi
# 1920: The Evil Returns           Vicky Ahuja
# 1971 (2007 film)              Manoj Bajpayee
# 2 States (2014 film)            Arjun Kapoor
# ...                                      ...
# Zindagi 50-50                    Veena Malik
# Zindagi Na Milegi Dobara      Hrithik Roshan
# Zindagi Tere Naam         Mithun Chakraborty
# Zokkomon                     Darsheel Safary
# Zor Lagaa Ke...Haiya!          Meghan Jadhav
#
# [1500 rows x 1 columns]

# %% [markdown]
# ##Series Maths Methods

# %%
# count -> give count of elements but dont consider missing values
# size -> do same work but consider missing values

print(vk.count())
print()
print(vk.size)
# Out:
# runs    215
# dtype: int64
#
# 215

# %%
# sum
print(subs.sum())
# Out:
# Subscribers gained    49510
# dtype: int64

# %%
# product
print(subs.product())
# Out:
# Subscribers gained    0
# dtype: int64

# %%
# mean
print(subs.mean())
# Out:
# Subscribers gained    135.643836
# dtype: float64

# %%
# median
print(vk.median())
# Out:
# runs    24.0
# dtype: float64

# %%
# mode -> which value has highest frequency
print(movies.mode())
# Out:
#            lead
# 0  Akshay Kumar

# %%
# std (standard deviation)
print(subs.std())
# Out:
# Subscribers gained    62.675023
# dtype: float64

# %%
# var (variance)
print(vk.var())
# Out:
# runs    688.002478
# dtype: float64

# %%
# min/max
print(subs.min())
# Out:
# Subscribers gained    33
# dtype: int64

# %%
# describe -> give summary
print(vk.describe())
# Out:
#              runs
# count  215.000000
# mean    30.855814
# std     26.229801
# min      0.000000
# 25%      9.000000
# 50%     24.000000
# 75%     48.000000
# max    113.000000

# %% [markdown]
# ##Series Indexing

# %%
# integer indexing
x = pd.Series([12,13,14,35,77,2,1,9])
x[0]
# Out:
# np.int64(12)

# %%
# negative indexing series
# DOES NOT WORKS

# %%
# fetching value from giving index
print(movies.iloc[0])
# Out:
# lead    Vicky Kaushal
# Name: Uri: The Surgical Strike, dtype: object

# %%
print(movies.iloc[-1])
# Out:
# lead    Akshay Kumar
# Name: Awara Paagal Deewana, dtype: object

# %%
print(vk.iloc[0])
# Out:
# runs    0
# Name: 8, dtype: int64

# %%
# Slicing
print(vk[5:16])
# Out:
#           runs
# match_no
# 207          0
# 135          0
# 130          0
# 211          0
# 106          1
# 204          1
# 113          1
# 77           1
# 1            1
# 5            1
# 75           1

# %%
print(vk[-5:])
# Out:
#           runs
# match_no
# 164        100
# 120        100
# 123        108
# 126        109
# 128        113

# %%
print(movies[-5:])
# Out:
#                                     lead
# movie
# Hum Tumhare Hain Sanam    Shah Rukh Khan
# Aankhen (2002 film)     Amitabh Bachchan
# Saathiya (film)             Vivek Oberoi
# Company (film)                Ajay Devgn
# Awara Paagal Deewana        Akshay Kumar

# %%
print(movies[::2])
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# The Accidental Prime Minister (film)       Anupam Kher
# Evening Shadows                       Mona Ambegaonkar
# Fraud Saiyaan                             Arshad Warsi
# Manikarnika: The Queen of Jhansi        Kangana Ranaut
# ...                                                ...
# Raaz (2002 film)                            Dino Morea
# Waisa Bhi Hota Hai Part II                Arshad Warsi
# Kaante                                Amitabh Bachchan
# Aankhen (2002 film)                   Amitabh Bachchan
# Company (film)                              Ajay Devgn
#
# [750 rows x 1 columns]

# %%
# fancy indexing
print(vk.iloc[[1,3,4,5]])
# Out:
#           runs
# match_no
# 87           0
# 91           0
# 206          0
# 207          0

# %%
# indexing with labels
print(movies.loc['The Accidental Prime Minister (film)'])
# Out:
# lead    Anupam Kher
# Name: The Accidental Prime Minister (film), dtype: object

# %% [markdown]
# ##Editing Series

# %%
# using indexing
custom
# Out:
# maths      67
# science    69
# english    99
# french     10
# dtype: int64

# %%
custom['sst'] = 100

# %%
print(custom)
# Out:
# maths       67
# science     69
# english     99
# french      10
# sst        100
# dtype: int64

# %%
# slicing
runs[2:4] = [100,100]
print(runs)
# Out:
# 0     13
# 1     45
# 2    100
# 3    100
# 4     55
# dtype: int64

# %%
# fancy indexing
runs[[0,3,4]] = [0,0,0]

# %%
print(runs)
# Out:
# 0      0
# 1     45
# 2    100
# 3      0
# 4      0
# dtype: int64

# %%
# using index label
# movies['2 States (2014 film)'] = 'Alia Bhatt'

# %%
print(movies.loc['2 States (2014 film)'])
# Out:
# lead    Arjun Kapoor
# Name: 2 States (2014 film), dtype: object

# %% [markdown]
# ##Series with python functionalities

# %%
# len/type/dir/sorted/min/max
print(len(subs))
print(type(subs))
# Out:
# 365
# <class 'pandas.core.frame.DataFrame'>

# %%
# dir -> show all attributes applicable
print(dir(subs))
# Out:
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__arrow_c_stream__', '__bool__', '__class__', '__contains__', '__copy__', '__dataframe__', '__dataframe_consortium_standard__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pandas_priority__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__'
# ...

# %%
print(sorted(subs))
# Out:
# ['Subscribers gained']

# %%
# sorted -> sort plus give output in list format
print(subs['Subscribers gained'].sort_values().to_list())
# Out:
# [33, 33, 35, 37, 39, 40, 40, 40, 40, 42, 42, 43, 44, 44, 44, 45, 46, 46, 48, 49, 49, 49, 49, 50, 50, 50, 51, 54, 56, 56, 56, 56, 57, 61, 62, 64, 65, 65, 66, 66, 66, 66, 67, 68, 70, 70, 70, 71, 71, 72, 72, 72, 72, 72, 73, 74, 74, 75, 76, 76, 76, 76, 77, 77, 78, 78, 78, 79, 79, 80, 80, 80, 81, 81, 82, 82, 83, 83, 83, 84, 84, 84, 85, 86, 86, 86, 87, 87, 87, 87, 88, 88, 88, 88, 88, 89, 89, 89, 90, 90, 90, 90, 91, 92, 92, 92, 93, 93, 93, 93, 95, 95, 96, 96, 96, 96, 97, 97, 98, 98, 99, 99, 100, 100, 100, 101, 101, 101, 102, 102, 103, 103, 104, 104, 104, 105, 105, 105, 105, 105, 105, 105, 105, 105, 108, 108, 108, 108, 108, 108, 109, 109, 110, 110, 110, 111, 111, 112, 113, 113, 113, 114, 114, 114, 114, 115, 115, 115, 115, 117, 117, 117, 118, 118, 119, 119, 119, 119, 120, 122, 123, 123, 123, 123, 123, 124, 125, 126, 127, 128, 128, 129, 130, 131, 131, 132, 132, 134, 134, 134, 135, 135, 136, 136, 136, 137, 138, 138, 138, 139, 140, 144, 145, 146, 146, 146, 146, 147, 149, 150, 150, 150, 150, 151,
# ...

# %%
print(subs['Subscribers gained'].min())
# Out:
# 33

# %%
print(subs['Subscribers gained'].max())
# Out:
# 396

# %%
# type conversion
list(custom)
# Out:
# [67, 69, 99, 10, 100]

# %%
dict(custom)
# Out:
# {'maths': np.int64(67),
#  'science': np.int64(69),
#  'english': np.int64(99),
#  'french': np.int64(10),
#  'sst': np.int64(100)}

# %%
# membership operator generally for indexes
'Why Cheat India' in movies.index
# Out:
# True

# %%
'Alia Bhatt' in movies.values
# Out:
# True

# %%
# looping -> use for values
for i in movies.values:
  print(i)
# Out:
# ['Vicky Kaushal']
# ['Vicky Ahuja']
# ['Anupam Kher']
# ['Emraan Hashmi']
# ['Mona Ambegaonkar']
# ['Geetika Vidya Ohlyan']
# ['Arshad Warsi']
# ['Radhika Apte']
# ['Kangana Ranaut']
# ['Nawazuddin Siddiqui']
# ['Ali Asgar']
# ['Ranveer Singh']
# ['Prit Kamani']
# ['Ajay Devgn']
# ['Sushant Singh Rajput']
# ['Amitabh Bachchan']
# ['Abhimanyu Dasani']
# ['Talha Arshad Reshi']
# ['Nawazuddin Siddiqui']
# ['Garima Agarwal']
# ['Rasika Agashe']
# ['Barun Sobti']
# ['Akshay Kumar']
# ['Zaheer Iqbal']
# ['Vidyut Jammwal']
# ['Deepika Amin']
# ['Manav Kaul']
# ['Naseeruddin Shah']
# ['Varun Dhawan']
# ['Shreyas Talpade']
# ['Tiger Shroff']
# ['Boman Irani']
# ['Ajay Devgn']
# ['Arjun Kapoor']
# ['Gavie Chahal']
# ['Prabhu Deva']
# ['Shahid Kapoor']
# ['Ayushmann Khurrana']
# ['Anupam Kher']
# ['Karanvir Bohra']
# ['Hrithik Roshan']
# ['Jimmy Sheirgill']
# ['John Abraham']
# ['Rishi Kapoor']
# ['Kangana Ranaut']
# ['Natalia Janoszek']
# ['Diljit Dosanjh']
# ['Sidharth Malhotra']
# ...

# %%
# arithematic operator (broadcasting)

print(100 - custom)
# Out:
# maths      33
# science    31
# english     1
# french     90
# sst         0
# dtype: int64

# %%
# Relational operators
print(vk >=50 )
# Out:
#            runs
# match_no
# 8         False
# 87        False
# 93        False
# 91        False
# 206       False
# ...         ...
# 164        True
# 120        True
# 123        True
# 126        True
# 128        True
#
# [215 rows x 1 columns]

# %% [markdown]
# ##Boolean Indexing on Series

# %%
# find no. of 50's and 100's scored
print(vk[vk>=50].dropna().size)
# Out:
# 50

# %%
# find number of ducks
print(vk[vk==0].dropna().size)
# Out:
# 9

# %%
# count number of days when more than 200 subs are gained
print(subs[subs['Subscribers gained'] > 200].size)
# Out:
# 59

# %%
# how many has made more than 20 movies
num_movies = movies.value_counts()
print(num_movies[num_movies > 20])
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %% [markdown]
# ##Plotting Graphs on Series

# %%
subs.plot()
# Out:
# <Axes: >

# %%
movies.value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='lead'>

# %%
movies.value_counts().head(20).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>
