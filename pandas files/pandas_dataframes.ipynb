# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ##Creating Dataframes

# %%
# using lists
student_data = [
    [100,44,50],
    [90,70,7],
    [120,100,14],
    [80,50,2]
]

print(pd.DataFrame(student_data, columns=['iq','marks','package']))
# Out:
#     iq  marks  package
# 0  100     44       50
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2
